# %%
import pandas as pd

URL = "http://data.insideairbnb.com/france/ile-de-france/paris/2024-09-06/visualisations/listings.csv"
df = pd.read_csv(URL)
df.head()
# Out:
#        id                                               name  host_id  \
# 0  371299  Marais Rue des Archives refait à neuf février ...  1870265
# 1  371862                         loft in Paris (Belleville)  1872631
# 2  372879            Appartement complet au centre de Paris.  1876396
# 3  375434  Luxurious Art & Design Flat, 180m2, Champs Ely...   683140
# 4  378897                        Little flat near Montmartre  1902818
#
#    host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0     Thomas                  NaN  Hôtel-de-Ville  48.85751    2.35511
# 1  Veronique                  NaN        Entrepôt  48.87151    2.37219
# 2     Samuel                  NaN        Gobelins  48.83593    2.35108
# 3      Oscar                  NaN          Élysée  48.86680    2.30972
# 4   Lorraine                  NaN           Opéra  48.88285    2.33462
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95461 entries, 0 to 95460
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              95461 non-null  int64
#  1   name                            95461 non-null  str
#  2   host_id                         95461 non-null  int64
#  3   host_name                       95455 non-null  str
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   95461 non-null  str
#  6   latitude                        95461 non-null  float64
#  7   longitude                       95461 non-null  float64
#  8   room_type                       95461 non-null  str
#  9   price                           64230 non-null  float64
#  10  minimum_nights                  95461 non-null  int64
#  11  number_of_reviews               95461 non-null  int64
# ...

# %% [markdown]
# **Filtres logiques : garde uniquement les logements où :**
# - price entre 20 et 1000 (on enlève les valeurs aberrantes)
# - minimum_nights <= 30

# %%
df = df[(df["price"]> 20) & (df["price"] < 1000) & (df["minimum_nights"] <= 30)]

# %% [markdown]
# **Top 10 quartiers par prix médian :**

# %%
df.groupby("neighbourhood")["price"].median().sort_values(ascending=False).head(10)
# Out:
# neighbourhood
# Élysée            240.0
# Louvre            221.0
# Luxembourg        220.0
# Palais-Bourbon    219.0
# Hôtel-de-Ville    200.0
# Passy             197.0
# Temple            190.0
# Opéra             180.0
# Bourse            180.0
# Panthéon          179.0
# Name: price, dtype: float64

# %% [markdown]
# **Bonus : Prix médian par room_type (Entire home, Private room, etc.).**

# %%
df.groupby("room_type")["price"].median().sort_values(ascending=False)
# Out:
# room_type
# Hotel room         268.0
# Entire home/apt    159.0
# Private room       107.0
# Shared room         52.0
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

top10 = df.groupby("neighbourhood")["price"].median().sort_values(ascending=False).head(10)
top10.plot(kind="barh")
plt.xlabel("Prix médian (€/nuit)")
plt.title("Top 10 quartiers Airbnb Paris")
plt.tight_layout()
plt.show()

# %% [markdown]
# Le jeu de données porte sur les airbnb à Paris. Le but de l'analyse est de suivre le prix médian.
# Si nous regardons les 10 quartiers les plus chers en fonction du prix médians nous obtenons :
# - Élysée  240.0€
# - Louvre 221.0€
# - Luxembourg 220.0€
# - Palais-Bourbon 219.0€
# - Hôtel-de-Ville 200.0€
# - Passy 197.0€
# - Temple 190.0€
# - Opéra 180.0€
# - Bourse 180.0€
# - Panthéon 179.0€
#
# Maintnenant regrdons le prix médian par type de chambre du plus chers au moins chers. Nous obtenons les Hotel room à 268.0€, Entire home/apt à 159.0€, Private room à 107.0€ et
# Shared room à 52.0€.
